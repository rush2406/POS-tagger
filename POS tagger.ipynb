# %%
import nltk
from nltk.corpus import brown
import numpy as np
from collections import Counter
from collections import defaultdict
from math import log
import time
import random

# %%
stime = time.time()
sentences = np.array(brown.tagged_sents())
words = brown.tagged_words()
tokens,taged = zip(*words)

# %%
total = len(words)
wordcount = Counter(tokens)
tokenTags = defaultdict(Counter)
for token, tag in words:
    tokenTags[token][tag] += 1.0

tagcount = Counter(taged)

bgram = nltk.ngrams(taged,2)
tagtags = defaultdict(Counter)
for tag1, tag2 in bgram:
    tagtags[tag1][tag2] += 1.0
    
t = list(sorted(set(taged)))

# %%
for x in tokenTags:
    for y in tokenTags[x]:
        a = tokenTags[x][y]
        b = tagcount[y]
        tokenTags[x][y] = a/b
        
for tag1 in tagtags:
    for tag2 in tagtags[tag1]:
        a = tagtags[tag1][tag2]
        b = tagcount[tag1]
        tagtags[tag1][tag2] = a/b
count=0

# %%
def viterbi(test):
    for idx,wrd in enumerate(test):
        if(idx==0):
            for i in t:
                w[idx][i] = tokenTags[wrd][i]
        else:
            for cur in t:
                q=0
                for prev in t:
                    x = tagtags[prev][cur]*tokenTags[wrd][cur]*w[idx-1][prev]
                    if(q<x):
                        q=x;
                        pos[idx][cur] = prev
                w[idx][cur]=q

# %%
def printing(test):
    q=0
    val=0
    flag=0
    c=0
    for i in t:
        if(q<w[len(test)-1][i]):
            q=w[len(test)-1][i]
            val=i
    for idx,wrd in enumerate(reversed(test)):
        print(wrd,val,tagans[len(test)-1-idx])
        if(val!=tagans[len(test)-1-idx]):
            flag=1
        val = pos[len(test)-1-idx][val]
    if(flag==1):
        c = c+1
    return c

# %%
for it in range(100):
    r = random.randint(0,len(sentences))
    tok,tagans = zip(*sentences[r])
    w = defaultdict(Counter)
    pos = defaultdict(Counter)
    viterbi(tok)
    count = count + printing(tok)
print(100-count)
# Out:
# . . .
# '' '' ''
# more RBR RBR
# any DTI QL
# school NN VB
# to IN-NC TO
# go VB-NC VB
# don't DO* DO*
# I PPSS PPSS
# `` `` ``
# . . .
# Jews NPS NPS
# the AT AT
# to TO-NC IN
# abhorrent JJ JJ
# were BED BED
# Shylock NP NP
# to IN IN
# attributed VBN VBN
# ideas NNS NNS
# the AT AT
# that WPO CS
# dramatist NN NN
# the AT AT
# shown VBN VBN
# have HV HV
# would MD MD
# Testament NN-TL NN-TL
# Old JJ-TL JJ-TL
# the AT-TL AT
# Reading VBG VBG
# . . .
# subject JJ NN
# the NIL AT
# in NIL IN
# courses NNS NNS
# distinguished VBN VBN
# even QL RB
# and CC CC
# adequate JJ JJ
# offer VB VB
# universities NNS NNS
# many AP AP
# , , ,
# this DT DT
# of IN IN
# spite NN NN
# In IN IN
# . . .
# '' '' ''
# done VBN VBN
# want VB VB
# you PPSS PPSS
# else RB RB
# anything PN PN
# for CS IN
# now RB RB
# ready JJ JJ
# all QL QL
# I'm PPSS+BEM PPSS+BEM
# that CS CS
# him PPO PPO
# to IN IN
# sayin' VBG VBG
# just RB RB
# was BEDZ BEDZ
# I PPSS PPSS
# `` `` ``
# . .-HL .
# week NN-HL NN
# a AT AT
# for CS IN
# it PPO PPO
# wear VB VB
# and CC CC
# , , ,
# wart NN NN
# the AT AT
# on RP IN
# it PPO PPO
# tie VB VB
# , , ,
# hours NNS NNS
# twenty-four CD CD
# for IN IN
# vinegar NN NN
# in IN-NC IN
# beef NN NN
# raw JJ JJ
# soak VB VB
# to TO TO
# was BEDZ BEDZ
# Another DT DT
# . . .
# Museum NN-TL NN-TL
# India NP-TL NP-TL
# East JJ-TL JJ-TL
# town's NN$ NN$
# the AT AT
# for IN IN
# items NNS NNS
# few AP AP
# a AT AT
# were BED BED
# Salem NP NP
# to IN IN
# back RB RB
# took VBD VBD
# Gibault NP NP
# Captain NN-TL NN-TL
# All ABN ABN
# . . .
# brush VB NN
# or CC CC
# rag NN NN
# clean JJ JJ
# a AT AT
# with IN IN
# dusting VBG VBG
# by IN IN
# clean JJ JJ
# kept VBN-HL VBN
# be BE-HL BE
# should MD-HL MD
# press NN-HL NN
# the AT-HL AT
# of IN-HL IN
# rest NN-HL NN
# The AT-HL AT
# . . .
# fast RB RB
# there EX RB
# of IN IN
# out RP RP
# got VBD VBD
# and CC CC
# team NN NN
# the AT AT
# at IN IN
# lashed VBD VBD
# and CC CC
# yelled VBD VBD
# , , ,
# buckboard NN NN
# the AT AT
# onto IN IN
# man NN-HL NN
# dead JJ-HL JJ
# the AT AT
# heaved VBD VBD
# He PPS PPS
# . 0 .
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-882991501a6f> in <module>
#       5     pos = defaultdict(Counter)
#       6     viterbi(tok)
# ----> 7     count = count + printing(tok)
#       8 print(100-count)
#
# <ipython-input-12-35ab4bcf3023> in printing(test)
#      10     for idx,wrd in enumerate(reversed(test)):
#      11         print(wrd,val,tagans[len(test)-1-idx])
# ---> 12         if(val[0]!=tagans[len(test)-1-idx][0]):
#      13             flag=1
#      14         val = pos[len(test)-1-idx][val]
#
# TypeError: 'int' object is not subscriptable
